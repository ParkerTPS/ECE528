# %%
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load the data
#
# The dataset contains 3636 training instances and 810 testing instances. Each timeseries corresponds to a measurement of engine noise captured by a vehicle sensor. For this task, the goal is to automatically detect the presence of a specific issue with
# the engine. The problem is a binary classification task. We will use the `Engine_TRAIN` file for training and the
# `Engine_TEST` file for testing. In these files, the first column corresponds to the label.

# %%
def readucr(filename):
    data = np.loadtxt(filename, delimiter="\t")
    y = data[:, 0]
    x = data[:, 1:]
    return x, y.astype(int)

x_train, y_train = readucr("Engine_TRAIN.tsv")
x_test, y_test = readucr("Engine_TEST.tsv")

# %% [markdown]
# ## Visualize the data
#
# Here we visualize one timeseries example for each of the two classes in the dataset.

# %%
classes = np.unique(np.concatenate((y_train, y_test), axis=0))

plt.figure()
for c in classes:
    c_x_train = x_train[y_train == c]
    plt.plot(c_x_train[0], label="class " + str(c))
plt.legend(loc="best")
plt.show()
plt.close()

# %% [markdown]
# ## Standardize the data
#
# Our timeseries instances have a fixed length of 500 samples. The data is already z-normalized: each timeseries sample has a mean equal to zero and a standard deviation equal to one. This type of normalization is very common for timeseries classification problems. Note that the timeseries data used here are univariate, meaning we only have one channel per timeseries example. We will therefore transform the timeseries into a multivariate one with one channel using a simple reshaping via numpy. This will allow us to construct a model that is easily applicable to multivariate time series.

# %%
x_train.shape
# Out:
# (3636, 500)

# %%
x_test.shape
# Out:
# (810, 500)

# %%
x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))
x_train.shape
# Out:
# (3636, 500, 1)

# %%
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))
x_test.shape
# Out:
# (810, 500, 1)

# %% [markdown]
# Finally, in order to use `sparse_categorical_crossentropy`, we will have to count
# the number of classes beforehand.

# %%
num_classes = len(np.unique(y_train))

# %% [markdown]
# Now we shuffle the training set because we will be using the `validation_split` option
# later when training.

# %%
idx = np.random.permutation(len(x_train))
x_train = x_train[idx]
y_train = y_train[idx]

# %% [markdown]
# Standardize the labels to positive integers.
# The expected labels will then be 0 and 1.

# %%
y_train[y_train == -1] = 0
y_test[y_test == -1] = 0

# %% [markdown]
# ## Build a model
#
# This is where you define your model. A simple model is provided.

# %%
def make_model(input_shape):
    input_layer = keras.layers.Input(input_shape)

    conv1 = keras.layers.Conv1D(filters=64, kernel_size=12, padding="same")(input_layer)
    LN_1 = keras.layers.BatchNormalization()(conv1)
    conv1 = keras.layers.ReLU()(LN_1)

    conv2 = keras.layers.Conv1D(filters=64, kernel_size=12, padding="same")(conv1)
    LN_2 = keras.layers.BatchNormalization()(conv2)
    conv2 = keras.layers.ReLU()(LN_2)

    flat1 = keras.layers.Flatten()(conv2)
   
    dense1 = keras.layers.Dense(512, activation="relu")(flat1)
    dense1 = keras.layers.Dropout(0.5)(dense1)

    output_layer = keras.layers.Dense(num_classes, activation="softmax")(dense1)

    return keras.models.Model(inputs=input_layer, outputs=output_layer)


model = make_model(input_shape=x_train.shape[1:])
keras.utils.plot_model(model, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %% [markdown]
# ## Train the model
#
# This is where you specify and update hyperparameters for the training.

# %%
epochs = 100
batch_size = 32

callbacks = [
    keras.callbacks.ModelCheckpoint(
        "best_model.h5", save_best_only=True, monitor="val_loss"
    )
]
model.compile(
    optimizer="sgd",
    loss="sparse_categorical_crossentropy",
    metrics=["sparse_categorical_accuracy"],
)
history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.2,
    verbose=1,
)
# Out:
# Epoch 1/100
# 91/91 [==============================] - 3s 10ms/step - loss: 0.6351 - sparse_categorical_accuracy: 0.7215 - val_loss: 0.7072 - val_sparse_categorical_accuracy: 0.5055
# Epoch 2/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.3053 - sparse_categorical_accuracy: 0.8666 - val_loss: 0.9898 - val_sparse_categorical_accuracy: 0.5055
# Epoch 3/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.2378 - sparse_categorical_accuracy: 0.9027 - val_loss: 0.8697 - val_sparse_categorical_accuracy: 0.5124
# Epoch 4/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.1856 - sparse_categorical_accuracy: 0.9243 - val_loss: 0.7122 - val_sparse_categorical_accuracy: 0.6209
# Epoch 5/100
# 91/91 [==============================] - 1s 8ms/step - loss: 0.1492 - sparse_categorical_accuracy: 0.9395 - val_loss: 0.2712 - val_sparse_categorical_accuracy: 0.8599
# Epoch 6/100
# 91/91 [==============================] - 1s 8ms/step - loss: 0.1152 - sparse_categorical_accuracy: 0.9567 - val_loss: 0.2249 - val_sparse_categorical_accuracy: 0.9025
# Epoch 7/100
# 91/91 [==============================] - 1s 8ms/step - loss: 0.1016 - sparse_categorical_accuracy: 0.9660 - val_loss: 0.1932 - val_sparse_categorical_accuracy: 0.9286
# Epoch 8/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0965 - sparse_categorical_accuracy: 0.9670 - val_loss: 0.2329 - val_sparse_categorical_accuracy: 0.9135
# Epoch 9/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0578 - sparse_categorical_accuracy: 0.9845 - val_loss: 0.1992 - val_sparse_categorical_accuracy: 0.9299
# Epoch 10/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0536 - sparse_categorical_accuracy: 0.9845 - val_loss: 0.2412 - val_sparse_categorical_accuracy: 0.9080
# Epoch 11/100
# 91/91 [==============================] - 1s 8ms/step - loss: 0.0513 - sparse_categorical_accuracy: 0.9866 - val_loss: 0.1910 - val_sparse_categorical_accuracy: 0.9245
# Epoch 12/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0429 - sparse_categorical_accuracy: 0.9887 - val_loss: 0.2189 - val_sparse_categorical_accuracy: 0.9025
# Epoch 13/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0330 - sparse_categorical_accuracy: 0.9931 - val_loss: 0.2080 - val_sparse_categorical_accuracy: 0.9107
# Epoch 14/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0236 - sparse_categorical_accuracy: 0.9966 - val_loss: 0.2216 - val_sparse_categorical_accuracy: 0.9148
# Epoch 15/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0268 - sparse_categorical_accuracy: 0.9948 - val_loss: 0.2159 - val_sparse_categorical_accuracy: 0.9148
# Epoch 16/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0224 - sparse_categorical_accuracy: 0.9942 - val_loss: 0.2177 - val_sparse_categorical_accuracy: 0.9052
# Epoch 17/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0160 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.1959 - val_sparse_categorical_accuracy: 0.9299
# Epoch 18/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0163 - sparse_categorical_accuracy: 0.9969 - val_loss: 0.2143 - val_sparse_categorical_accuracy: 0.9313
# Epoch 19/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0137 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.2164 - val_sparse_categorical_accuracy: 0.9190
# Epoch 20/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0132 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.2386 - val_sparse_categorical_accuracy: 0.9093
# Epoch 21/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0125 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.2120 - val_sparse_categorical_accuracy: 0.9176
# Epoch 22/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0144 - sparse_categorical_accuracy: 0.9976 - val_loss: 0.2264 - val_sparse_categorical_accuracy: 0.9162
# Epoch 23/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0137 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.2245 - val_sparse_categorical_accuracy: 0.9382
# Epoch 24/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0141 - sparse_categorical_accuracy: 0.9972 - val_loss: 0.2480 - val_sparse_categorical_accuracy: 0.9080
# Epoch 25/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0094 - sparse_categorical_accuracy: 0.9990 - val_loss: 0.2098 - val_sparse_categorical_accuracy: 0.9368
# Epoch 26/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0076 - sparse_categorical_accuracy: 0.9993 - val_loss: 0.2109 - val_sparse_categorical_accuracy: 0.9286
# Epoch 27/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0106 - sparse_categorical_accuracy: 0.9976 - val_loss: 0.2368 - val_sparse_categorical_accuracy: 0.9231
# Epoch 28/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0104 - sparse_categorical_accuracy: 0.9976 - val_loss: 0.2405 - val_sparse_categorical_accuracy: 0.9162
# Epoch 29/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0073 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2165 - val_sparse_categorical_accuracy: 0.9258
# Epoch 30/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0070 - sparse_categorical_accuracy: 0.9993 - val_loss: 0.2175 - val_sparse_categorical_accuracy: 0.9341
# Epoch 31/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0079 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.2276 - val_sparse_categorical_accuracy: 0.9203
# Epoch 32/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0093 - sparse_categorical_accuracy: 0.9990 - val_loss: 0.2379 - val_sparse_categorical_accuracy: 0.9162
# Epoch 33/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0074 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.2157 - val_sparse_categorical_accuracy: 0.9286
# Epoch 34/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0057 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2086 - val_sparse_categorical_accuracy: 0.9313
# Epoch 35/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0072 - sparse_categorical_accuracy: 0.9993 - val_loss: 0.2390 - val_sparse_categorical_accuracy: 0.9203
# Epoch 36/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0079 - sparse_categorical_accuracy: 0.9990 - val_loss: 0.2409 - val_sparse_categorical_accuracy: 0.9135
# Epoch 37/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0058 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.2175 - val_sparse_categorical_accuracy: 0.9245
# Epoch 38/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0045 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2148 - val_sparse_categorical_accuracy: 0.9368
# Epoch 39/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0059 - sparse_categorical_accuracy: 0.9990 - val_loss: 0.2376 - val_sparse_categorical_accuracy: 0.9148
# Epoch 40/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0042 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.2213 - val_sparse_categorical_accuracy: 0.9258
# Epoch 41/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0043 - sparse_categorical_accuracy: 0.9993 - val_loss: 0.2120 - val_sparse_categorical_accuracy: 0.9327
# Epoch 42/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0147 - sparse_categorical_accuracy: 0.9959 - val_loss: 0.2529 - val_sparse_categorical_accuracy: 0.9148
# Epoch 43/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0069 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.2284 - val_sparse_categorical_accuracy: 0.9286
# Epoch 44/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0051 - sparse_categorical_accuracy: 0.9993 - val_loss: 0.2186 - val_sparse_categorical_accuracy: 0.9299
# Epoch 45/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0049 - sparse_categorical_accuracy: 0.9993 - val_loss: 0.2216 - val_sparse_categorical_accuracy: 0.9327
# Epoch 46/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0052 - sparse_categorical_accuracy: 0.9993 - val_loss: 0.2276 - val_sparse_categorical_accuracy: 0.9231
# Epoch 47/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0037 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.2963 - val_sparse_categorical_accuracy: 0.9093
# Epoch 48/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0026 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2298 - val_sparse_categorical_accuracy: 0.9286
# Epoch 49/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0042 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.2395 - val_sparse_categorical_accuracy: 0.9286
# Epoch 50/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0028 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2625 - val_sparse_categorical_accuracy: 0.9176
# Epoch 51/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0026 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2396 - val_sparse_categorical_accuracy: 0.9245
# Epoch 52/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0052 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.2522 - val_sparse_categorical_accuracy: 0.9217
# Epoch 53/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0042 - sparse_categorical_accuracy: 0.9993 - val_loss: 0.2560 - val_sparse_categorical_accuracy: 0.9354
# Epoch 54/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0038 - sparse_categorical_accuracy: 0.9993 - val_loss: 0.2339 - val_sparse_categorical_accuracy: 0.9272
# Epoch 55/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0032 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2351 - val_sparse_categorical_accuracy: 0.9299
# Epoch 56/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0022 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2338 - val_sparse_categorical_accuracy: 0.9245
# Epoch 57/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0018 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2411 - val_sparse_categorical_accuracy: 0.9327
# Epoch 58/100
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0028 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.2395 - val_sparse_categorical_accuracy: 0.9286
# Epoch 59/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0020 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2525 - val_sparse_categorical_accuracy: 0.9190
# Epoch 60/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0046 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.2369 - val_sparse_categorical_accuracy: 0.9245
# Epoch 61/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0030 - sparse_categorical_accuracy: 0.9993 - val_loss: 0.2395 - val_sparse_categorical_accuracy: 0.9327
# Epoch 62/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0027 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.2333 - val_sparse_categorical_accuracy: 0.9258
# Epoch 63/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0042 - sparse_categorical_accuracy: 0.9990 - val_loss: 0.2334 - val_sparse_categorical_accuracy: 0.9231
# Epoch 64/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0026 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.2497 - val_sparse_categorical_accuracy: 0.9135
# Epoch 65/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0028 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.2548 - val_sparse_categorical_accuracy: 0.9148
# Epoch 66/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0021 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2423 - val_sparse_categorical_accuracy: 0.9258
# Epoch 67/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0016 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2456 - val_sparse_categorical_accuracy: 0.9341
# Epoch 68/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0015 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2478 - val_sparse_categorical_accuracy: 0.9272
# Epoch 69/100
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0014 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2449 - val_sparse_categorical_accuracy: 0.9272
# Epoch 70/100
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0019 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.2524 - val_sparse_categorical_accuracy: 0.9217
# Epoch 71/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0074 - sparse_categorical_accuracy: 0.9990 - val_loss: 0.2694 - val_sparse_categorical_accuracy: 0.9231
# Epoch 72/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0062 - sparse_categorical_accuracy: 0.9976 - val_loss: 0.2891 - val_sparse_categorical_accuracy: 0.9121
# Epoch 73/100
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0032 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2470 - val_sparse_categorical_accuracy: 0.9272
# Epoch 74/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0074 - sparse_categorical_accuracy: 0.9972 - val_loss: 0.2718 - val_sparse_categorical_accuracy: 0.9135
# Epoch 75/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0030 - sparse_categorical_accuracy: 0.9993 - val_loss: 0.3133 - val_sparse_categorical_accuracy: 0.9107
# Epoch 76/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0036 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.2503 - val_sparse_categorical_accuracy: 0.9231
# Epoch 77/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0019 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2489 - val_sparse_categorical_accuracy: 0.9203
# Epoch 78/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0021 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2348 - val_sparse_categorical_accuracy: 0.9299
# Epoch 79/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0033 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.2389 - val_sparse_categorical_accuracy: 0.9203
# Epoch 80/100
# 91/91 [==============================] - 1s 6ms/step - loss: 0.0021 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.2432 - val_sparse_categorical_accuracy: 0.9327
# Epoch 81/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0029 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2516 - val_sparse_categorical_accuracy: 0.9245
# Epoch 82/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0022 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2725 - val_sparse_categorical_accuracy: 0.9135
# Epoch 83/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0018 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2500 - val_sparse_categorical_accuracy: 0.9299
# Epoch 84/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0015 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2553 - val_sparse_categorical_accuracy: 0.9203
# Epoch 85/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0018 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.2619 - val_sparse_categorical_accuracy: 0.9327
# Epoch 86/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0018 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.2536 - val_sparse_categorical_accuracy: 0.9176
# Epoch 87/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0021 - sparse_categorical_accuracy: 0.9990 - val_loss: 0.2451 - val_sparse_categorical_accuracy: 0.9286
# Epoch 88/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0018 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.3074 - val_sparse_categorical_accuracy: 0.9080
# Epoch 89/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0023 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.2595 - val_sparse_categorical_accuracy: 0.9190
# Epoch 90/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0026 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.2433 - val_sparse_categorical_accuracy: 0.9245
# Epoch 91/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0012 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2513 - val_sparse_categorical_accuracy: 0.9231
# Epoch 92/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0015 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2716 - val_sparse_categorical_accuracy: 0.9190
# Epoch 93/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0015 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2534 - val_sparse_categorical_accuracy: 0.9299
# Epoch 94/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0019 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.2570 - val_sparse_categorical_accuracy: 0.9217
# Epoch 95/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0017 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.2498 - val_sparse_categorical_accuracy: 0.9341
# Epoch 96/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0018 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.2456 - val_sparse_categorical_accuracy: 0.9368
# Epoch 97/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0011 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2579 - val_sparse_categorical_accuracy: 0.9203
# Epoch 98/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0011 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.2555 - val_sparse_categorical_accuracy: 0.9217
# Epoch 99/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0019 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.2777 - val_sparse_categorical_accuracy: 0.9148
# Epoch 100/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0011 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2544 - val_sparse_categorical_accuracy: 0.9245

# %% [markdown]
# ## Evaluate model on test data

# %%
model = keras.models.load_model("best_model.h5")

test_loss, test_acc = model.evaluate(x_test, y_test)

print("Test accuracy", test_acc)
print("Test loss", test_loss)
# Out:
# 26/26 [==============================] - 0s 3ms/step - loss: 0.6395 - sparse_categorical_accuracy: 0.7556
# Test accuracy 0.7555555701255798
# Test loss 0.639494776725769

# %% [markdown]
# ## Plot the model's training and validation loss

# %%
metric = "sparse_categorical_accuracy"
plt.figure()
plt.plot(history.history[metric])
plt.plot(history.history["val_" + metric])
plt.title("model " + metric)
plt.ylabel(metric, fontsize="large")
plt.xlabel("epoch", fontsize="large")
plt.legend(["train", "val"], loc="best")
plt.show()
plt.close()
