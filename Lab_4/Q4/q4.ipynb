# %%
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load the data
#
# The dataset contains 3636 training instances and 810 testing instances. Each timeseries corresponds to a measurement of engine noise captured by a vehicle sensor. For this task, the goal is to automatically detect the presence of a specific issue with
# the engine. The problem is a binary classification task. We will use the `Engine_TRAIN` file for training and the
# `Engine_TEST` file for testing. In these files, the first column corresponds to the label.

# %%
def readucr(filename):
    data = np.loadtxt(filename, delimiter="\t")
    y = data[:, 0]
    x = data[:, 1:]
    return x, y.astype(int)

x_train, y_train = readucr("Engine_TRAIN.tsv")
x_test, y_test = readucr("Engine_TEST.tsv")

# %% [markdown]
# ## Visualize the data
#
# Here we visualize one timeseries example for each of the two classes in the dataset.

# %%
classes = np.unique(np.concatenate((y_train, y_test), axis=0))

plt.figure()
for c in classes:
    c_x_train = x_train[y_train == c]
    plt.plot(c_x_train[0], label="class " + str(c))
plt.legend(loc="best")
plt.show()
plt.close()

# %% [markdown]
# ## Standardize the data
#
# Our timeseries instances have a fixed length of 500 samples. The data is already z-normalized: each timeseries sample has a mean equal to zero and a standard deviation equal to one. This type of normalization is very common for timeseries classification problems. Note that the timeseries data used here are univariate, meaning we only have one channel per timeseries example. We will therefore transform the timeseries into a multivariate one with one channel using a simple reshaping via numpy. This will allow us to construct a model that is easily applicable to multivariate time series.

# %%
x_train.shape
# Out:
# (3636, 500)

# %%
x_test.shape
# Out:
# (810, 500)

# %%
x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))
x_train.shape
# Out:
# (3636, 500, 1)

# %%
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))
x_test.shape
# Out:
# (810, 500, 1)

# %% [markdown]
# Finally, in order to use `sparse_categorical_crossentropy`, we will have to count
# the number of classes beforehand.

# %%
num_classes = len(np.unique(y_train))

# %% [markdown]
# Now we shuffle the training set because we will be using the `validation_split` option
# later when training.

# %%
idx = np.random.permutation(len(x_train))
x_train = x_train[idx]
y_train = y_train[idx]

# %% [markdown]
# Standardize the labels to positive integers.
# The expected labels will then be 0 and 1.

# %%
y_train[y_train == -1] = 0
y_test[y_test == -1] = 0

# %% [markdown]
# ## Build a model
#
# This is where you define your model. A simple model is provided.

# %%
def make_model(input_shape):
    input_layer = keras.layers.Input(input_shape)

    conv1 = keras.layers.Conv1D(filters=64, kernel_size=12, padding="same")(input_layer)
    LN_1 = keras.layers.BatchNormalization()(conv1)
    conv1 = keras.layers.ReLU()(LN_1)

    conv2 = keras.layers.Conv1D(filters=64, kernel_size=12, padding="same")(conv1)
    LN_2 = keras.layers.BatchNormalization()(conv2)
    conv2 = keras.layers.ReLU()(LN_2)

    flat1 = keras.layers.Flatten()(conv2)
   
    dense1 = keras.layers.Dense(512, activation="relu")(flat1)
    dense1 = keras.layers.Dropout(0.5)(dense1)

    output_layer = keras.layers.Dense(num_classes, activation="softmax")(dense1)

    return keras.models.Model(inputs=input_layer, outputs=output_layer)


model = make_model(input_shape=x_train.shape[1:])
keras.utils.plot_model(model, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %% [markdown]
# ## Train the model
#
# This is where you specify and update hyperparameters for the training.

# %%
epochs = 100
batch_size = 32

callbacks = [
    keras.callbacks.ModelCheckpoint(
        "best_model.h5", save_best_only=True, monitor="val_loss"
    )
]
model.compile(
    optimizer="sgd",
    loss="sparse_categorical_crossentropy",
    metrics=["sparse_categorical_accuracy"],
)
history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.2,
    verbose=1,
)
# Out:
# Epoch 1/100
# 91/91 [==============================] - 2s 9ms/step - loss: 0.6544 - sparse_categorical_accuracy: 0.7297 - val_loss: 0.8226 - val_sparse_categorical_accuracy: 0.5096
# Epoch 2/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.3017 - sparse_categorical_accuracy: 0.8700 - val_loss: 1.2405 - val_sparse_categorical_accuracy: 0.5096
# Epoch 3/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.2409 - sparse_categorical_accuracy: 0.8924 - val_loss: 1.0529 - val_sparse_categorical_accuracy: 0.5124
# Epoch 4/100
# 91/91 [==============================] - 1s 8ms/step - loss: 0.1871 - sparse_categorical_accuracy: 0.9288 - val_loss: 0.4085 - val_sparse_categorical_accuracy: 0.7720
# Epoch 5/100
# 91/91 [==============================] - 1s 8ms/step - loss: 0.1670 - sparse_categorical_accuracy: 0.9326 - val_loss: 0.2659 - val_sparse_categorical_accuracy: 0.8750
# Epoch 6/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.1219 - sparse_categorical_accuracy: 0.9580 - val_loss: 0.3122 - val_sparse_categorical_accuracy: 0.8544
# Epoch 7/100
# 91/91 [==============================] - 1s 8ms/step - loss: 0.0915 - sparse_categorical_accuracy: 0.9694 - val_loss: 0.1741 - val_sparse_categorical_accuracy: 0.9231
# Epoch 8/100
# 91/91 [==============================] - 1s 8ms/step - loss: 0.0743 - sparse_categorical_accuracy: 0.9780 - val_loss: 0.1698 - val_sparse_categorical_accuracy: 0.9245
# Epoch 9/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0701 - sparse_categorical_accuracy: 0.9783 - val_loss: 0.1925 - val_sparse_categorical_accuracy: 0.9107
# Epoch 10/100
# 91/91 [==============================] - 1s 8ms/step - loss: 0.0536 - sparse_categorical_accuracy: 0.9852 - val_loss: 0.1660 - val_sparse_categorical_accuracy: 0.9272
# Epoch 11/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0519 - sparse_categorical_accuracy: 0.9866 - val_loss: 0.1672 - val_sparse_categorical_accuracy: 0.9258
# Epoch 12/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0407 - sparse_categorical_accuracy: 0.9911 - val_loss: 0.1708 - val_sparse_categorical_accuracy: 0.9272
# Epoch 13/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0370 - sparse_categorical_accuracy: 0.9900 - val_loss: 0.1698 - val_sparse_categorical_accuracy: 0.9299
# Epoch 14/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0243 - sparse_categorical_accuracy: 0.9955 - val_loss: 0.1725 - val_sparse_categorical_accuracy: 0.9299
# Epoch 15/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0281 - sparse_categorical_accuracy: 0.9962 - val_loss: 0.1933 - val_sparse_categorical_accuracy: 0.9217
# Epoch 16/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0310 - sparse_categorical_accuracy: 0.9928 - val_loss: 0.1703 - val_sparse_categorical_accuracy: 0.9258
# Epoch 17/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0236 - sparse_categorical_accuracy: 0.9969 - val_loss: 0.1666 - val_sparse_categorical_accuracy: 0.9299
# Epoch 18/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0166 - sparse_categorical_accuracy: 0.9969 - val_loss: 0.1827 - val_sparse_categorical_accuracy: 0.9327
# Epoch 19/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0172 - sparse_categorical_accuracy: 0.9969 - val_loss: 0.1839 - val_sparse_categorical_accuracy: 0.9217
# Epoch 20/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0122 - sparse_categorical_accuracy: 0.9993 - val_loss: 0.1806 - val_sparse_categorical_accuracy: 0.9286
# Epoch 21/100
# 91/91 [==============================] - 1s 8ms/step - loss: 0.0135 - sparse_categorical_accuracy: 0.9972 - val_loss: 0.1644 - val_sparse_categorical_accuracy: 0.9327
# Epoch 22/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0154 - sparse_categorical_accuracy: 0.9972 - val_loss: 0.1672 - val_sparse_categorical_accuracy: 0.9272
# Epoch 23/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0108 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.1863 - val_sparse_categorical_accuracy: 0.9258
# Epoch 24/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0120 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.1816 - val_sparse_categorical_accuracy: 0.9258
# Epoch 25/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0087 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.1879 - val_sparse_categorical_accuracy: 0.9231
# Epoch 26/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0101 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.1994 - val_sparse_categorical_accuracy: 0.9231
# Epoch 27/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0105 - sparse_categorical_accuracy: 0.9993 - val_loss: 0.2151 - val_sparse_categorical_accuracy: 0.9176
# Epoch 28/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0079 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.2057 - val_sparse_categorical_accuracy: 0.9313
# Epoch 29/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0058 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2072 - val_sparse_categorical_accuracy: 0.9245
# Epoch 30/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0056 - sparse_categorical_accuracy: 0.9993 - val_loss: 0.1874 - val_sparse_categorical_accuracy: 0.9313
# Epoch 31/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0047 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1905 - val_sparse_categorical_accuracy: 0.9286
# Epoch 32/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0062 - sparse_categorical_accuracy: 0.9990 - val_loss: 0.2166 - val_sparse_categorical_accuracy: 0.9176
# Epoch 33/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0058 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2058 - val_sparse_categorical_accuracy: 0.9245
# Epoch 34/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0050 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.1996 - val_sparse_categorical_accuracy: 0.9258
# Epoch 35/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0044 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.2003 - val_sparse_categorical_accuracy: 0.9286
# Epoch 36/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0068 - sparse_categorical_accuracy: 0.9993 - val_loss: 0.1967 - val_sparse_categorical_accuracy: 0.9327
# Epoch 37/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0048 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.2013 - val_sparse_categorical_accuracy: 0.9341
# Epoch 38/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0075 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.2189 - val_sparse_categorical_accuracy: 0.9231
# Epoch 39/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0070 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.1899 - val_sparse_categorical_accuracy: 0.9286
# Epoch 40/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0046 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2077 - val_sparse_categorical_accuracy: 0.9245
# Epoch 41/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0076 - sparse_categorical_accuracy: 0.9993 - val_loss: 0.2034 - val_sparse_categorical_accuracy: 0.9258
# Epoch 42/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0079 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.2389 - val_sparse_categorical_accuracy: 0.9135
# Epoch 43/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0049 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.2344 - val_sparse_categorical_accuracy: 0.9217
# Epoch 44/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0067 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.1964 - val_sparse_categorical_accuracy: 0.9286
# Epoch 45/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0040 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2047 - val_sparse_categorical_accuracy: 0.9299
# Epoch 46/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0048 - sparse_categorical_accuracy: 0.9990 - val_loss: 0.2134 - val_sparse_categorical_accuracy: 0.9258
# Epoch 47/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0037 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2177 - val_sparse_categorical_accuracy: 0.9272
# Epoch 48/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0040 - sparse_categorical_accuracy: 0.9993 - val_loss: 0.2023 - val_sparse_categorical_accuracy: 0.9299
# Epoch 49/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0068 - sparse_categorical_accuracy: 0.9990 - val_loss: 0.2030 - val_sparse_categorical_accuracy: 0.9272
# Epoch 50/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0043 - sparse_categorical_accuracy: 0.9993 - val_loss: 0.1979 - val_sparse_categorical_accuracy: 0.9286
# Epoch 51/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0037 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1988 - val_sparse_categorical_accuracy: 0.9299
# Epoch 52/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0035 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2093 - val_sparse_categorical_accuracy: 0.9272
# Epoch 53/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0023 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2158 - val_sparse_categorical_accuracy: 0.9272
# Epoch 54/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0030 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.2176 - val_sparse_categorical_accuracy: 0.9245
# Epoch 55/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0030 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2052 - val_sparse_categorical_accuracy: 0.9313
# Epoch 56/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0021 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2067 - val_sparse_categorical_accuracy: 0.9299
# Epoch 57/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0028 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.2004 - val_sparse_categorical_accuracy: 0.9299
# Epoch 58/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0031 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.2113 - val_sparse_categorical_accuracy: 0.9245
# Epoch 59/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0024 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.2264 - val_sparse_categorical_accuracy: 0.9245
# Epoch 60/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0019 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2146 - val_sparse_categorical_accuracy: 0.9258
# Epoch 61/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0022 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2080 - val_sparse_categorical_accuracy: 0.9313
# Epoch 62/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0019 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2046 - val_sparse_categorical_accuracy: 0.9272
# Epoch 63/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0015 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2073 - val_sparse_categorical_accuracy: 0.9299
# Epoch 64/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0025 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2252 - val_sparse_categorical_accuracy: 0.9258
# Epoch 65/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0038 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.2034 - val_sparse_categorical_accuracy: 0.9245
# Epoch 66/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0017 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2084 - val_sparse_categorical_accuracy: 0.9245
# Epoch 67/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0016 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2106 - val_sparse_categorical_accuracy: 0.9272
# Epoch 68/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0017 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2105 - val_sparse_categorical_accuracy: 0.9258
# Epoch 69/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0026 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.2149 - val_sparse_categorical_accuracy: 0.9258
# Epoch 70/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0014 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2087 - val_sparse_categorical_accuracy: 0.9272
# Epoch 71/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0014 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.2191 - val_sparse_categorical_accuracy: 0.9258
# Epoch 72/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0015 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2163 - val_sparse_categorical_accuracy: 0.9245
# Epoch 73/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0015 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2113 - val_sparse_categorical_accuracy: 0.9245
# Epoch 74/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0017 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2159 - val_sparse_categorical_accuracy: 0.9286
# Epoch 75/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0015 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2222 - val_sparse_categorical_accuracy: 0.9258
# Epoch 76/100
# 91/91 [==============================] - 1s 7ms/step - loss: 9.8581e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2239 - val_sparse_categorical_accuracy: 0.9286
# Epoch 77/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0018 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2198 - val_sparse_categorical_accuracy: 0.9299
# Epoch 78/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0018 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2130 - val_sparse_categorical_accuracy: 0.9286
# Epoch 79/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0015 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2182 - val_sparse_categorical_accuracy: 0.9299
# Epoch 80/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0020 - sparse_categorical_accuracy: 0.9993 - val_loss: 0.2238 - val_sparse_categorical_accuracy: 0.9245
# Epoch 81/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0016 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2070 - val_sparse_categorical_accuracy: 0.9286
# Epoch 82/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0014 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2113 - val_sparse_categorical_accuracy: 0.9272
# Epoch 83/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0013 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2163 - val_sparse_categorical_accuracy: 0.9258
# Epoch 84/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0011 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2175 - val_sparse_categorical_accuracy: 0.9286
# Epoch 85/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0011 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2162 - val_sparse_categorical_accuracy: 0.9286
# Epoch 86/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0014 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2158 - val_sparse_categorical_accuracy: 0.9272
# Epoch 87/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0021 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.2249 - val_sparse_categorical_accuracy: 0.9258
# Epoch 88/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0011 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2182 - val_sparse_categorical_accuracy: 0.9272
# Epoch 89/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0019 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.2139 - val_sparse_categorical_accuracy: 0.9272
# Epoch 90/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0019 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.2066 - val_sparse_categorical_accuracy: 0.9258
# Epoch 91/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0016 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2114 - val_sparse_categorical_accuracy: 0.9299
# Epoch 92/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0015 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.2349 - val_sparse_categorical_accuracy: 0.9299
# Epoch 93/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0013 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2238 - val_sparse_categorical_accuracy: 0.9231
# Epoch 94/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0024 - sparse_categorical_accuracy: 0.9993 - val_loss: 0.2158 - val_sparse_categorical_accuracy: 0.9299
# Epoch 95/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0011 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2192 - val_sparse_categorical_accuracy: 0.9313
# Epoch 96/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0067 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.2116 - val_sparse_categorical_accuracy: 0.9286
# Epoch 97/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0019 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2114 - val_sparse_categorical_accuracy: 0.9341
# Epoch 98/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0018 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.2207 - val_sparse_categorical_accuracy: 0.9245
# Epoch 99/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0015 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2235 - val_sparse_categorical_accuracy: 0.9286
# Epoch 100/100
# 91/91 [==============================] - 1s 7ms/step - loss: 9.2557e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2199 - val_sparse_categorical_accuracy: 0.9313

# %% [markdown]
# ## Evaluate model on test data

# %%
model = keras.models.load_model("best_model.h5")

test_loss, test_acc = model.evaluate(x_test, y_test)

print("Test accuracy", test_acc)
print("Test loss", test_loss)
# Out:
# 26/26 [==============================] - 0s 3ms/step - loss: 0.6915 - sparse_categorical_accuracy: 0.7531
# Test accuracy 0.7530864477157593
# Test loss 0.691494882106781

# %% [markdown]
# ## Plot the model's training and validation loss

# %%
metric = "sparse_categorical_accuracy"
plt.figure()
plt.plot(history.history[metric])
plt.plot(history.history["val_" + metric])
plt.title("model " + metric)
plt.ylabel(metric, fontsize="large")
plt.xlabel("epoch", fontsize="large")
plt.legend(["train", "val"], loc="best")
plt.show()
plt.close()
