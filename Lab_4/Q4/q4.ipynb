# %%
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load the data
#
# The dataset contains 3636 training instances and 810 testing instances. Each timeseries corresponds to a measurement of engine noise captured by a vehicle sensor. For this task, the goal is to automatically detect the presence of a specific issue with
# the engine. The problem is a binary classification task. We will use the `Engine_TRAIN` file for training and the
# `Engine_TEST` file for testing. In these files, the first column corresponds to the label.

# %%
def readucr(filename):
    data = np.loadtxt(filename, delimiter="\t")
    y = data[:, 0]
    x = data[:, 1:]
    return x, y.astype(int)

x_train, y_train = readucr("Engine_TRAIN.tsv")
x_test, y_test = readucr("Engine_TEST.tsv")

# %% [markdown]
# ## Visualize the data
#
# Here we visualize one timeseries example for each of the two classes in the dataset.

# %%
classes = np.unique(np.concatenate((y_train, y_test), axis=0))

plt.figure()
for c in classes:
    c_x_train = x_train[y_train == c]
    plt.plot(c_x_train[0], label="class " + str(c))
plt.legend(loc="best")
plt.show()
plt.close()

# %% [markdown]
# ## Standardize the data
#
# Our timeseries instances have a fixed length of 500 samples. The data is already z-normalized: each timeseries sample has a mean equal to zero and a standard deviation equal to one. This type of normalization is very common for timeseries classification problems. Note that the timeseries data used here are univariate, meaning we only have one channel per timeseries example. We will therefore transform the timeseries into a multivariate one with one channel using a simple reshaping via numpy. This will allow us to construct a model that is easily applicable to multivariate time series.

# %%
x_train.shape
# Out:
# (3636, 500)

# %%
x_test.shape
# Out:
# (810, 500)

# %%
x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))
x_train.shape
# Out:
# (3636, 500, 1)

# %%
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))
x_test.shape
# Out:
# (810, 500, 1)

# %% [markdown]
# Finally, in order to use `sparse_categorical_crossentropy`, we will have to count
# the number of classes beforehand.

# %%
num_classes = len(np.unique(y_train))

# %% [markdown]
# Now we shuffle the training set because we will be using the `validation_split` option
# later when training.

# %%
idx = np.random.permutation(len(x_train))
x_train = x_train[idx]
y_train = y_train[idx]

# %% [markdown]
# Standardize the labels to positive integers.
# The expected labels will then be 0 and 1.

# %%
y_train[y_train == -1] = 0
y_test[y_test == -1] = 0

# %% [markdown]
# ## Build a model
#
# This is where you define your model. A simple model is provided.

# %%
def make_model(input_shape):
    input_layer = keras.layers.Input(input_shape)

    conv1 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(input_layer)
    LN_1 = keras.layers.LayerNormalization()(conv1)
    conv1 = keras.layers.ReLU()(LN_1)

    conv2 = keras.layers.Conv1D(filters=128, kernel_size=3, padding="same")(conv1)
    LN_2 = keras.layers.LayerNormalization()(conv2)
    conv2 = keras.layers.ReLU()(LN_2)

    # conv3 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(conv2)
    # LN_3 = keras.layers.LayerNormalization()(conv3)
    # conv3 = keras.layers.ReLU()(LN_3)

    flat1 = keras.layers.Flatten()(conv2)
    
    dense1 = keras.layers.Dense(256, activation="tanh")(flat1)
    dense1 = keras.layers.Dropout(0.5)(dense1)
    
    # dense2 = keras.layers.Dense(64, activation="tanh")(dense1)
    # dense2 = keras.layers.Dropout(0.5)(dense2)

    output_layer = keras.layers.Dense(num_classes, activation="softmax")(dense1)

    return keras.models.Model(inputs=input_layer, outputs=output_layer)


model = make_model(input_shape=x_train.shape[1:])
keras.utils.plot_model(model, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %% [markdown]
# ## Train the model
#
# This is where you specify and update hyperparameters for the training.

# %%
epochs = 50
batch_size = 32

callbacks = [
    keras.callbacks.ModelCheckpoint(
        "best_model.h5", save_best_only=True, monitor="val_loss"
    )
]
model.compile(
    optimizer="sgd",
    loss="sparse_categorical_crossentropy",
    metrics=["sparse_categorical_accuracy"],
)
history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.2,
    verbose=1,
)
# Out:
# Epoch 1/50
# 91/91 [==============================] - 38s 407ms/step - loss: 0.0684 - sparse_categorical_accuracy: 0.9746 - val_loss: 0.3926 - val_sparse_categorical_accuracy: 0.8448
# Epoch 2/50
# 32/91 [=========>....................] - ETA: 22s - loss: 0.0537 - sparse_categorical_accuracy: 0.9844
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\ptpsm\OneDrive\Documents\ECE528\Lab_4\Q4\q4.ipynb Cell 20 line 1
#       <a href='vscode-notebook-cell:/c%3A/Users/ptpsm/OneDrive/Documents/ECE528/Lab_4/Q4/q4.ipynb#X25sZmlsZQ%3D%3D?line=3'>4</a> callbacks = [
#       <a href='vscode-notebook-cell:/c%3A/Users/ptpsm/OneDrive/Documents/ECE528/Lab_4/Q4/q4.ipynb#X25sZmlsZQ%3D%3D?line=4'>5</a>     keras.callbacks.ModelCheckpoint(
#       <a href='vscode-notebook-cell:/c%3A/Users/ptpsm/OneDrive/Documents/ECE528/Lab_4/Q4/q4.ipynb#X25sZmlsZQ%3D%3D?line=5'>6</a>         "best_model.h5", save_best_only=True, monitor="val_loss"
#       <a href='vscode-notebook-cell:/c%3A/Users/ptpsm/OneDrive/Documents/ECE528/Lab_4/Q4/q4.ipynb#X25sZmlsZQ%3D%3D?line=6'>7</a>     )
#       <a href='vscode-notebook-cell:/c%3A/Users/ptpsm/OneDrive/Documents/ECE528/Lab_4/Q4/q4.ipynb#X25sZmlsZQ%3D%3D?line=7'>8</a> ]
#       <a href='vscode-notebook-cell:/c%3A/Users/ptpsm/OneDrive/Documents/ECE528/Lab_4/Q4/q4.ipynb#X25sZmlsZQ%3D%3D?line=8'>9</a> model.compile(
#      <a href='vscode-notebook-cell:/c%3A/Users/ptpsm/OneDrive/Documents/ECE528/Lab_4/Q4/q4.ipynb#X25sZmlsZQ%3D%3D?line=9'>10</a>     optimizer="sgd",
#      <a href='vscode-notebook-cell:/c%3A/Users/ptpsm/OneDrive/Documents/ECE528/Lab_4/Q4/q4.ipynb#X25sZmlsZQ%3D%3D?line=10'>11</a>     loss="sparse_categorical_crossentropy",
#      <a href='vscode-notebook-cell:/c%3A/Users/ptpsm/OneDrive/Documents/ECE528/Lab_4/Q4/q4.ipynb#X25sZmlsZQ%3D%3D?line=11'>12</a>     metrics=["sparse_categorical_accuracy"],
#      <a href='vscode-notebook-cell:/c%3A/Users/ptpsm/OneDrive/Documents/ECE528/Lab_4/Q4/q4.ipynb#X25sZmlsZQ%3D%3D?line=12'>13</a> )
# ---> <a href='vscode-notebook-cell:/c%3A/Users/ptpsm/OneDrive/Documents/ECE528/Lab_4/Q4/q4.ipynb#X25sZmlsZQ%3D%3D?line=13'>14</a> history = model.fit(
#      <a href='vscode-notebook-cell:/c%3A/Users/ptpsm/OneDrive/Documents/ECE528/Lab_4/Q4/q4.ipynb#X25sZmlsZQ%3D%3D?line=14'>15</a>     x_train,
#      <a href='vscode-notebook-cell:/c%3A/Users/ptpsm/OneDrive/Documents/ECE528/Lab_4/Q4/q4.ipynb#X25sZmlsZQ%3D%3D?line=15'>16</a>     y_train,
#      <a href='vscode-notebook-cell:/c%3A/Users/ptpsm/OneDrive/Documents/ECE528/Lab_4/Q4/q4.ipynb#X25sZmlsZQ%3D%3D?line=16'>17</a>     batch_size=batch_size,
#      <a href='vscode-notebook-cell:/c%3A/Users/ptpsm/OneDrive/Documents/ECE528/Lab_4/Q4/q4.ipynb#X25sZmlsZQ%3D%3D?line=17'>18</a>     epochs=epochs,
#      <a href='vscode-notebook-cell:/c%3A/Users/ptpsm/OneDrive/Documents/ECE528/Lab_4/Q4/q4.ipynb#X25sZmlsZQ%3D%3D?line=18'>19</a>     callbacks=callbacks,
#      <a href='vscode-notebook-cell:/c%3A/Users/ptpsm/OneDrive/Documents/ECE528/Lab_4/Q4/q4.ipynb#X25sZmlsZQ%3D%3D?line=19'>20</a>     validation_split=0.2,
#      <a href='vscode-notebook-cell:/c%3A/Users/ptpsm/OneDrive/Documents/ECE528/Lab_4/Q4/q4.ipynb#X25sZmlsZQ%3D%3D?line=20'>21</a>     verbose=1,
#      <a href='vscode-notebook-cell:/c%3A/Users/ptpsm/OneDrive/Documents/ECE528/Lab_4/Q4/q4.ipynb#X25sZmlsZQ%3D%3D?line=21'>22</a> )
#
# File c:\Users\ptpsm\.conda\envs\tf\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\ptpsm\.conda\envs\tf\lib\site-packages\keras\engine\training.py:1570, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1568 logs = tmp_logs
#    1569 end_step = step + data_handler.step_increment
# -> 1570 callbacks.on_train_batch_end(end_step, logs)
#    1571 if self.stop_training:
#    1572     break
#
# File c:\Users\ptpsm\.conda\envs\tf\lib\site-packages\keras\callbacks.py:470, in CallbackList.on_train_batch_end(self, batch, logs)
#     463 """Calls the `on_train_batch_end` methods of its callbacks.
#     464
#     465 Args:
#     466     batch: Integer, index of batch within the current epoch.
#     467     logs: Dict. Aggregated metric results up until this batch.
#     468 """
#     469 if self._should_call_train_batch_hooks:
# --> 470     self._call_batch_hook(ModeKeys.TRAIN, "end", batch, logs=logs)
#
# File c:\Users\ptpsm\.conda\envs\tf\lib\site-packages\keras\callbacks.py:317, in CallbackList._call_batch_hook(self, mode, hook, batch, logs)
#     315     self._call_batch_begin_hook(mode, batch, logs)
#     316 elif hook == "end":
# --> 317     self._call_batch_end_hook(mode, batch, logs)
#     318 else:
#     319     raise ValueError(
#     320         f"Unrecognized hook: {hook}. "
#     321         'Expected values are ["begin", "end"]'
#     322     )
#
# File c:\Users\ptpsm\.conda\envs\tf\lib\site-packages\keras\callbacks.py:340, in CallbackList._call_batch_end_hook(self, mode, batch, logs)
#     337     batch_time = time.time() - self._batch_start_time
#     338     self._batch_times.append(batch_time)
# --> 340 self._call_batch_hook_helper(hook_name, batch, logs)
#     342 if len(self._batch_times) >= self._num_batches_for_timing_check:
#     343     end_hook_name = hook_name
#
# File c:\Users\ptpsm\.conda\envs\tf\lib\site-packages\keras\callbacks.py:388, in CallbackList._call_batch_hook_helper(self, hook_name, batch, logs)
#     386 for callback in self.callbacks:
#     387     hook = getattr(callback, hook_name)
# --> 388     hook(batch, logs)
#     390 if self._check_timing:
#     391     if hook_name not in self._hook_times:
#
# File c:\Users\ptpsm\.conda\envs\tf\lib\site-packages\keras\callbacks.py:1081, in ProgbarLogger.on_train_batch_end(self, batch, logs)
#    1080 def on_train_batch_end(self, batch, logs=None):
# -> 1081     self._batch_update_progbar(batch, logs)
#
# File c:\Users\ptpsm\.conda\envs\tf\lib\site-packages\keras\callbacks.py:1157, in ProgbarLogger._batch_update_progbar(self, batch, logs)
#    1153     self.seen += add_seen
#    1155 if self.verbose == 1:
#    1156     # Only block async when verbose = 1.
# -> 1157     logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1158     self.progbar.update(self.seen, list(logs.items()), finalize=False)
#
# File c:\Users\ptpsm\.conda\envs\tf\lib\site-packages\keras\utils\tf_utils.py:635, in sync_to_numpy_or_python_type(tensors)
#     632         return t
#     633     return t.item() if np.ndim(t) == 0 else t
# --> 635 return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#
# File c:\Users\ptpsm\.conda\envs\tf\lib\site-packages\tensorflow\python\util\nest.py:917, in map_structure(func, *structure, **kwargs)
#     913 flat_structure = (flatten(s, expand_composites) for s in structure)
#     914 entries = zip(*flat_structure)
#     916 return pack_sequence_as(
# --> 917     structure[0], [func(*x) for x in entries],
#     918     expand_composites=expand_composites)
#
# File c:\Users\ptpsm\.conda\envs\tf\lib\site-packages\tensorflow\python\util\nest.py:917, in <listcomp>(.0)
#     913 flat_structure = (flatten(s, expand_composites) for s in structure)
#     914 entries = zip(*flat_structure)
#     916 return pack_sequence_as(
# --> 917     structure[0], [func(*x) for x in entries],
#     918     expand_composites=expand_composites)
#
# File c:\Users\ptpsm\.conda\envs\tf\lib\site-packages\keras\utils\tf_utils.py:628, in sync_to_numpy_or_python_type.<locals>._to_single_numpy_or_python_type(t)
#     625 def _to_single_numpy_or_python_type(t):
#     626     # Don't turn ragged or sparse tensors to NumPy.
#     627     if isinstance(t, tf.Tensor):
# --> 628         t = t.numpy()
#     629     # Strings, ragged and sparse tensors don't have .item(). Return them
#     630     # as-is.
#     631     if not isinstance(t, (np.ndarray, np.generic)):
#
# File c:\Users\ptpsm\.conda\envs\tf\lib\site-packages\tensorflow\python\framework\ops.py:1157, in _EagerTensorBase.numpy(self)
#    1134 """Copy of the contents of this Tensor into a NumPy array or scalar.
#    1135
#    1136 Unlike NumPy arrays, Tensors are immutable, so this method has to copy
#    (...)
#    1154     NumPy dtype.
#    1155 """
#    1156 # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1157 maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1158 return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#
# File c:\Users\ptpsm\.conda\envs\tf\lib\site-packages\tensorflow\python\framework\ops.py:1123, in _EagerTensorBase._numpy(self)
#    1121 def _numpy(self):
#    1122   try:
# -> 1123     return self._numpy_internal()
#    1124   except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1125     raise core._status_to_exception(e) from None
#
# KeyboardInterrupt:

# %% [markdown]
# ## Evaluate model on test data

# %%
model = keras.models.load_model("best_model.h5")

test_loss, test_acc = model.evaluate(x_test, y_test)

print("Test accuracy", test_acc)
print("Test loss", test_loss)
# Out:
# 26/26 [==============================] - 0s 3ms/step - loss: 0.8511 - sparse_categorical_accuracy: 0.6370
# Test accuracy 0.6370370388031006
# Test loss 0.8511038422584534

# %% [markdown]
# ## Plot the model's training and validation loss

# %%
metric = "sparse_categorical_accuracy"
plt.figure()
plt.plot(history.history[metric])
plt.plot(history.history["val_" + metric])
plt.title("model " + metric)
plt.ylabel(metric, fontsize="large")
plt.xlabel("epoch", fontsize="large")
plt.legend(["train", "val"], loc="best")
plt.show()
plt.close()
